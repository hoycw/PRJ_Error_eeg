# %%
#%matplotlib inline
import sys 
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.io as io
import pickle
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
SBJ = 'RATE18'

# %%
prj_dir = '/Volumes/hoycw_clust/PRJ_Error_eeg/'
results_dir = prj_dir+'results/'
fig_type = '.png'
data_dir = prj_dir+'data/'
sbj_dir  = data_dir+SBJ+'/'

# Get log names
logs = {}
with open(data_dir+'TT_ratings_behav_log_list.txt') as f:
    for line in f:
        (sbj, log_name) = line.split(',')
        logs[sbj] = log_name.replace('\n','')

# %% [markdown]
# ### Load SBJ Data

# %%
log_fname = os.path.join(sbj_dir,'00_raw',logs[SBJ])

log_file = open(log_fname,'r')
log = log_file.readlines()
log_file.close()

# %% [markdown]
# ### Process Version-Specific Parameters

# %%
prdm = {}
for line in log:
    # Script version
    if line.find('paradigm_name =')!=-1:
        prdm['prdm_name'] = line[line.find('= ')+2:line.find('\n')]
    if line.find('paradigm_version =')!=-1:
        prdm['prdm_version'] = line[line.find('= ')+2:line.find('\n')]

    # Timing variables
    if line.find('interval_dur =')!=-1:
        prdm['target'] = float(line[line.find('= ')+2:line.find('\n')])
    if line.find('feedback_delay =')!=-1:
        prdm['fb_delay'] = float(line[line.find('= ')+2:line.find('\n')])
    if line.find('feedback_dur =')!=-1:
        prdm['fb'] = float(line[line.find('= ')+2:line.find('\n')])
    if line.find('bad_fb_tolerance =')!=-1:
        prdm['bad_fb_tolerance'] = float(line[line.find('= ')+2:line.find('\n')])
    if line.find('rating_delay =')!=-1:
        prdm['rating_delay'] = float(line[line.find('= ')+2:line.find('\n')])
    if line.find('max_rating_time =')!=-1:
        prdm['max_rating_time'] = float(line[line.find('= ')+2:line.find('\n')])
    
    # ITIs and boundaries between them
    if line.find('ITIs')!=-1:
        prdm['ITIs'] = [float(string) \
                    for string in line[line.find('[')+1:line.find(']')].split(',')]
        ITI_bounds = np.mean([prdm['ITIs'][:-1], prdm['ITIs'][1:]],0)
        
    # Tolerance limits/clamps
    if line.find('tolerance_lim')!=-1:
        prdm['tol_lim'] = [float(string) \
                         for string in line[line.find('[')+1:line.find(']')].split(',')]
        
    # Trial count variables
    if line.find('n_blocks')!=-1:
        prdm['n_blocks'] = int(line[line.find('=')+2:])
    if line.find('n_trials')!=-1:
        prdm['n_trials'] = int(line[line.find('=')+2:])
    if line.find('n_examples')!=-1:
        prdm['n_examples'] = int(line[line.find('=')+2:])
    elif line.find('n_fullvis')!=-1:
        prdm['n_examples'] = int(line[line.find('=')+2:])
    if line.find('n_training')!=-1:
        prdm['n_training'] = int(line[line.find('=')+2:])

# Add missing items from early log files
if 'prdm_name' not in prdm:
    prdm['prdm_name'] = 'not_logged'
if 'prdm_version' not in prdm:
    prdm['prdm_version'] = '<1.8.5'
if 'n_examples' not in prdm:
    prdm['n_examples'] = int(-1)
if 'n_training' not in prdm:
    prdm['n_training'] = int(-1)

prdm['trl_len'] = prdm['target']+\
            prdm['fb_delay']+prdm['fb']
prdm['rating_trl_len'] = prdm['target']+prdm['rating_delay']+\
            prdm['fb_delay']+prdm['fb']

# %% [markdown]
# ### Save paradigm parameters

# %%
# Python readable
prdm_fname = os.path.join(sbj_dir,'03_events',SBJ+'_prdm_vars.pkl')
with open(prdm_fname, 'wb') as f:
    pickle.dump(prdm, f, pickle.HIGHEST_PROTOCOL)
# MATLAB Readable
prdm_fname = os.path.join(sbj_dir,'03_events',SBJ+'_prdm_vars.mat')
io.savemat(prdm_fname,prdm)

# %%
print 'paradigm: ', prdm['prdm_name'], ' v', prdm['prdm_version']
print
print 'interval: ', prdm['target'], 's'
print 'feedback_delay: ', prdm['fb_delay'], 's'
print 'rating_delay: ', prdm['rating_delay'], 's'
print 'max_rating_time: ', prdm['max_rating_time'], 's'
print 'feedback duration: ', prdm['fb'], 's'
print 'total trial length: ', prdm['trl_len'], 's'
print
print 'n_blocks: ', prdm['n_blocks']
print 'n_trials/block: ', prdm['n_trials']
print 'n_full_vis_examples: ', prdm['n_examples']
print 'n_training/condition: ', prdm['n_training']
print
# ITI_bounds = [np.mean(a,b) for a, b in zip(ITIs[:-1],ITIs[1:])]
print 'ITIs:',prdm['ITIs'], ITI_bounds
print 'tolerance_lim:', prdm['tol_lim']
# Out:
# paradigm:  target_time_ratings  v 3.1
#
# interval:  1.0 s
# feedback_delay:  0.8 s
# rating_delay:  1.0 s
# max_rating_time:  20.0 s
# feedback duration:  1.0 s
# total trial length:  2.8 s
#
# n_blocks:  3
# n_trials/block:  75
# n_full_vis_examples:  5
# n_training/condition:  15
#
# ITIs: [0.7, 1.0] [ 0.85]
# tolerance_lim: [0.4, 0.015]

# %% [markdown]
# ### Extract Trial Info

# %%
rating_lines
# Out:
# ['471.8790 \tDATA \tB0_T0: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.17\n',
#  '475.6976 \tDATA \tB0_T1: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.18200000000000002\n',
#  '481.1784 \tDATA \tB0_T2: Rating = 88; rating_RT = 1.651; condition = easy; tolerance = 0.17900000000000002\n',
#  '485.6819 \tDATA \tB0_T3: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.17600000000000002\n',
#  '489.1988 \tDATA \tB0_T4: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.18800000000000003\n',
#  '495.3150 \tDATA \tB0_T5: Rating = 94; rating_RT = 2.288; condition = easy; tolerance = 0.18500000000000003\n',
#  '500.1302 \tDATA \tB0_T6: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.18200000000000002\n',
#  '503.6286 \tDATA \tB0_T7: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.19400000000000003\n',
#  '509.2485 \tDATA \tB0_T8: Rating = 91; rating_RT = 2.086; condition = easy; tolerance = 0.19100000000000003\n',
#  '514.0450 \tDATA \tB0_T9: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.18800000000000003\n',
#  '517.8651 \tDATA \tB0_T10: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.18500000000000003\n',
#  '523.1447 \tDATA \tB0_T11: Rating = 97; rating_RT = 1.449; condition = easy; tolerance = 0.18200000000000002\n',
#  '527.9484 \tDATA \tB0_T12: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.17900000000000002\n',
#  '531.4613 \tDATA \tB0_T13: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.17600000000000002\n',
#  '536.4142 \tDATA \tB0_T14: Rating = 100; rating_RT = 1.42; condition = easy; tolerance = 0.17300000000000001\n',
#  '540.9111 \tDATA \tB0_T15: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.17300000000000001\n',
#  '544.4459 \tDATA \tB0_T16: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.17\n',
#  '549.2807 \tDATA \tB0_T17: Rating = 100; rating_RT = 1.316; condition = easy; tolerance = 0.18200000000000002\n',
#  '553.7778 \tDATA \tB0_T18: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.17900000000000002\n',
#  '557.6309 \tDATA \tB0_T19: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.17600000000000002\n',
#  '563.1446 \tDATA \tB0_T20: Rating = 100; rating_RT = 2.014; condition = easy; tolerance = 0.17600000000000002\n',
#  '567.6478 \tDATA \tB0_T21: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.17300000000000001\n',
#  '571.4610 \tDATA \tB0_T22: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.17\n',
#  '577.4642 \tDATA \tB0_T23: Rating = 71; rating_RT = 2.469; condition = easy; tolerance = 0.167\n',
#  '581.9608 \tDATA \tB0_T24: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.167\n',
#  '585.7809 \tDATA \tB0_T25: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.164\n',
#  '591.9773 \tDATA \tB0_T26: Rating = 47; rating_RT = 2.366; condition = easy; tolerance = 0.17600000000000002\n',
#  '596.7974 \tDATA \tB0_T27: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.17300000000000001\n',
#  '600.2974 \tDATA \tB0_T28: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.17300000000000001\n',
#  '605.6971 \tDATA \tB0_T29: Rating = 89; rating_RT = 1.572; condition = easy; tolerance = 0.17\n',
#  '610.1970 \tDATA \tB0_T30: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.167\n',
#  '614.0104 \tDATA \tB0_T31: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.164\n',
#  '618.8470 \tDATA \tB0_T32: Rating = 98; rating_RT = 1.303; condition = easy; tolerance = 0.161\n',
#  '623.3435 \tDATA \tB0_T33: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.17300000000000001\n',
#  '626.8637 \tDATA \tB0_T34: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.17\n',
#  '632.9267 \tDATA \tB0_T35: Rating = 72; rating_RT = 2.531; condition = easy; tolerance = 0.18200000000000002\n',
#  '637.7299 \tDATA \tB0_T36: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.19400000000000003\n',
#  '641.2432 \tDATA \tB0_T37: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.19100000000000003\n',
#  '646.4797 \tDATA \tB0_T38: Rating = 91; rating_RT = 1.405; condition = easy; tolerance = 0.18800000000000003\n',
#  '650.9766 \tDATA \tB0_T39: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20000000000000004\n',
#  '654.7933 \tDATA \tB0_T40: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.19700000000000004\n',
#  '678.5295 \tDATA \tB0_T41: Rating = None; rating_RT = 20; condition = easy; tolerance = 0.19400000000000003\n',
#  '683.1260 \tDATA \tB0_T42: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.19100000000000003\n',
#  '686.9464 \tDATA \tB0_T43: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.18800000000000003\n',
#  '692.2424 \tDATA \tB0_T44: Rating = 85; rating_RT = 1.766; condition = easy; tolerance = 0.20000000000000004\n',
#  '697.0458 \tDATA \tB0_T45: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.19700000000000004\n',
#  '700.8592 \tDATA \tB0_T46: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20900000000000005\n',
#  '710.0791 \tDATA \tB0_T47: Rating = 66; rating_RT = 5.689; condition = easy; tolerance = 0.22100000000000006\n',
#  '714.5753 \tDATA \tB0_T48: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22100000000000006\n',
#  '718.3959 \tDATA \tB0_T49: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.21800000000000005\n',
#  '723.3252 \tDATA \tB0_T50: Rating = 76; rating_RT = 1.396; condition = easy; tolerance = 0.21500000000000005\n',
#  '728.1457 \tDATA \tB0_T51: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22700000000000006\n',
#  '731.6420 \tDATA \tB0_T52: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22700000000000006\n',
#  '736.5788 \tDATA \tB0_T53: Rating = 98; rating_RT = 1.405; condition = easy; tolerance = 0.22400000000000006\n',
#  '741.3786 \tDATA \tB0_T54: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23600000000000007\n',
#  '745.1918 \tDATA \tB0_T55: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23300000000000007\n',
#  '750.7786 \tDATA \tB0_T56: Rating = 100; rating_RT = 1.756; condition = easy; tolerance = 0.23000000000000007\n',
#  '755.2787 \tDATA \tB0_T57: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.24200000000000008\n',
#  '758.7916 \tDATA \tB0_T58: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23900000000000007\n',
#  '763.9417 \tDATA \tB0_T59: Rating = 94; rating_RT = 1.318; condition = easy; tolerance = 0.23600000000000007\n',
#  '768.4450 \tDATA \tB0_T60: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23300000000000007\n',
#  '771.9580 \tDATA \tB0_T61: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23300000000000007\n',
#  '777.7281 \tDATA \tB0_T62: Rating = 95; rating_RT = 1.939; condition = easy; tolerance = 0.23000000000000007\n',
#  '782.2246 \tDATA \tB0_T63: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22700000000000006\n',
#  '786.0449 \tDATA \tB0_T64: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22400000000000006\n',
#  '792.2076 \tDATA \tB0_T65: Rating = 62; rating_RT = 2.331; condition = easy; tolerance = 0.22100000000000006\n',
#  '796.7281 \tDATA \tB0_T66: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23300000000000007\n',
#  '800.5281 \tDATA \tB0_T67: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23300000000000007\n',
#  '806.8243 \tDATA \tB0_T68: Rating = 58; rating_RT = 2.465; condition = easy; tolerance = 0.23000000000000007\n',
#  '811.3277 \tDATA \tB0_T69: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22700000000000006\n',
#  '814.8443 \tDATA \tB0_T70: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22400000000000006\n',
#  '819.7911 \tDATA \tB0_T71: Rating = 87; rating_RT = 1.403; condition = easy; tolerance = 0.22100000000000006\n',
#  '824.2740 \tDATA \tB0_T72: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.21800000000000005\n',
#  '827.7941 \tDATA \tB0_T73: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23000000000000007\n',
#  '832.7073 \tDATA \tB0_T74: Rating = 75; rating_RT = 1.38; condition = easy; tolerance = 0.22700000000000006\n',
#  '1117.5898 \tDATA \tB1_T0: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22700000000000006\n',
#  '1121.4036 \tDATA \tB1_T1: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22400000000000006\n',
#  '1126.4867 \tDATA \tB1_T2: Rating = 87; rating_RT = 1.552; condition = easy; tolerance = 0.22100000000000006\n',
#  '1131.2868 \tDATA \tB1_T3: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.21800000000000005\n',
#  '1135.1048 \tDATA \tB1_T4: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.21500000000000005\n',
#  '1140.3733 \tDATA \tB1_T5: Rating = 93; rating_RT = 1.435; condition = easy; tolerance = 0.21200000000000005\n',
#  '1145.1714 \tDATA \tB1_T6: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20900000000000005\n',
#  '1148.7067 \tDATA \tB1_T7: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20600000000000004\n',
#  '1153.8032 \tDATA \tB1_T8: Rating = 89; rating_RT = 1.584; condition = easy; tolerance = 0.21800000000000005\n',
#  '1158.3064 \tDATA \tB1_T9: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.21500000000000005\n',
#  '1162.1193 \tDATA \tB1_T10: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.21200000000000005\n',
#  '1166.8562 \tDATA \tB1_T11: Rating = 94; rating_RT = 1.204; condition = easy; tolerance = 0.20900000000000005\n',
#  '1171.3530 \tDATA \tB1_T12: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20900000000000005\n',
#  '1175.1709 \tDATA \tB1_T13: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20600000000000004\n',
#  '1179.7892 \tDATA \tB1_T14: Rating = 87; rating_RT = 1.084; condition = easy; tolerance = 0.20300000000000004\n',
#  '1184.2857 \tDATA \tB1_T15: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20000000000000004\n',
#  '1188.1228 \tDATA \tB1_T16: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20000000000000004\n',
#  '1193.2860 \tDATA \tB1_T17: Rating = 90; rating_RT = 1.648; condition = easy; tolerance = 0.21200000000000005\n',
#  '1197.7888 \tDATA \tB1_T18: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22400000000000006\n',
#  '1201.3024 \tDATA \tB1_T19: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22100000000000006\n',
#  '1205.9890 \tDATA \tB1_T20: Rating = 86; rating_RT = 1.153; condition = easy; tolerance = 0.23300000000000007\n',
#  '1210.7857 \tDATA \tB1_T21: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23000000000000007\n',
#  '1214.3023 \tDATA \tB1_T22: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.24200000000000008\n',
#  '1219.4554 \tDATA \tB1_T23: Rating = 87; rating_RT = 1.318; condition = easy; tolerance = 0.25400000000000006\n',
#  '1224.2522 \tDATA \tB1_T24: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.25400000000000006\n',
#  '1227.7723 \tDATA \tB1_T25: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.25100000000000006\n',
#  '1232.8853 \tDATA \tB1_T26: Rating = 91; rating_RT = 1.581; condition = easy; tolerance = 0.26300000000000007\n',
#  '1237.3888 \tDATA \tB1_T27: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.26000000000000006\n',
#  '1240.9021 \tDATA \tB1_T28: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.25700000000000006\n',
#  '1245.7219 \tDATA \tB1_T29: Rating = 94; rating_RT = 1.289; condition = easy; tolerance = 0.2690000000000001\n',
#  '1250.2219 \tDATA \tB1_T30: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.26600000000000007\n',
#  '1253.7350 \tDATA \tB1_T31: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.26300000000000007\n',
#  '1258.6717 \tDATA \tB1_T32: Rating = 89; rating_RT = 1.104; condition = easy; tolerance = 0.26000000000000006\n',
#  '1263.1684 \tDATA \tB1_T33: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.25700000000000006\n',
#  '1266.6884 \tDATA \tB1_T34: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.25400000000000006\n',
#  '1272.1680 \tDATA \tB1_T35: Rating = 83; rating_RT = 1.648; condition = easy; tolerance = 0.25100000000000006\n',
#  '1276.6711 \tDATA \tB1_T36: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.26300000000000007\n',
#  '1280.4882 \tDATA \tB1_T37: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.26000000000000006\n',
#  '1285.3677 \tDATA \tB1_T38: Rating = 77; rating_RT = 1.049; condition = easy; tolerance = 0.25700000000000006\n',
#  '1289.8713 \tDATA \tB1_T39: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.25700000000000006\n',
#  '1293.6880 \tDATA \tB1_T40: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.25400000000000006\n',
#  '1299.0174 \tDATA \tB1_T41: Rating = 77; rating_RT = 1.499; condition = easy; tolerance = 0.25100000000000006\n',
#  '1303.5173 \tDATA \tB1_T42: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.26300000000000007\n',
#  '1307.3378 \tDATA \tB1_T43: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.26000000000000006\n',
#  '1312.3509 \tDATA \tB1_T44: Rating = 72; rating_RT = 1.179; condition = easy; tolerance = 0.25700000000000006\n',
#  '1317.1546 \tDATA \tB1_T45: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.25400000000000006\n',
#  '1320.9675 \tDATA \tB1_T46: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.25100000000000006\n',
#  '1325.6374 \tDATA \tB1_T47: Rating = 75; rating_RT = 1.139; condition = easy; tolerance = 0.24800000000000005\n',
#  '1330.1375 \tDATA \tB1_T48: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.24500000000000005\n',
#  '1333.6507 \tDATA \tB1_T49: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.24200000000000005\n',
#  '1338.4371 \tDATA \tB1_T50: Rating = 93; rating_RT = 1.251; condition = easy; tolerance = 0.23900000000000005\n',
#  '1342.9541 \tDATA \tB1_T51: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23600000000000004\n',
#  '1346.7506 \tDATA \tB1_T52: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23600000000000004\n',
#  '1351.6703 \tDATA \tB1_T53: Rating = 81; rating_RT = 1.089; condition = easy; tolerance = 0.23300000000000004\n',
#  '1356.4705 \tDATA \tB1_T54: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23000000000000004\n',
#  '1359.9837 \tDATA \tB1_T55: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22700000000000004\n',
#  '1365.6368 \tDATA \tB1_T56: Rating = 97; rating_RT = 1.821; condition = easy; tolerance = 0.22400000000000003\n',
#  '1370.1365 \tDATA \tB1_T57: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23600000000000004\n',
#  '1373.6504 \tDATA \tB1_T58: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23600000000000004\n',
#  '1378.5032 \tDATA \tB1_T59: Rating = 83; rating_RT = 1.018; condition = easy; tolerance = 0.23300000000000004\n',
#  '1383.3001 \tDATA \tB1_T60: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.23000000000000004\n',
#  '1387.1201 \tDATA \tB1_T61: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22700000000000004\n',
#  '1392.1664 \tDATA \tB1_T62: Rating = 86; rating_RT = 1.515; condition = easy; tolerance = 0.22400000000000003\n',
#  '1396.9697 \tDATA \tB1_T63: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22400000000000003\n',
#  '1400.4835 \tDATA \tB1_T64: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22100000000000003\n',
#  '1405.4196 \tDATA \tB1_T65: Rating = 99; rating_RT = 1.106; condition = easy; tolerance = 0.21800000000000003\n',
#  '1409.9360 \tDATA \tB1_T66: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.21500000000000002\n',
#  '1413.4331 \tDATA \tB1_T67: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.21500000000000002\n',
#  '1418.1359 \tDATA \tB1_T68: Rating = 96; rating_RT = 1.17; condition = easy; tolerance = 0.21200000000000002\n',
#  '1422.9330 \tDATA \tB1_T69: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20900000000000002\n',
#  '1426.7528 \tDATA \tB1_T70: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20600000000000002\n',
#  '1431.7991 \tDATA \tB1_T71: Rating = 95; rating_RT = 1.515; condition = easy; tolerance = 0.203\n',
#  '1436.6027 \tDATA \tB1_T72: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.2\n',
#  '1440.1194 \tDATA \tB1_T73: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.197\n',
#  '1444.7692 \tDATA \tB1_T74: Rating = 97; rating_RT = 1.122; condition = easy; tolerance = 0.194\n',
#  '1655.4162 \tDATA \tB2_T0: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03500000000000003\n',
#  '1659.2499 \tDATA \tB2_T1: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.02300000000000003\n',
#  '1664.8159 \tDATA \tB2_T2: Rating = 82; rating_RT = 2.056; condition = hard; tolerance = 0.02600000000000003\n',
#  '1669.3163 \tDATA \tB2_T3: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.02900000000000003\n',
#  '1672.8295 \tDATA \tB2_T4: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03200000000000003\n',
#  '1677.9823 \tDATA \tB2_T5: Rating = 84; rating_RT = 1.323; condition = hard; tolerance = 0.03500000000000003\n',
#  '1682.7793 \tDATA \tB2_T6: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.02300000000000003\n',
#  '1686.5996 \tDATA \tB2_T7: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.015\n',
#  '1691.6957 \tDATA \tB2_T8: Rating = 53; rating_RT = 1.565; condition = hard; tolerance = 0.018\n',
#  '1696.4987 \tDATA \tB2_T9: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.015\n',
#  '1700.0172 \tDATA \tB2_T10: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.018\n',
#  '1705.5817 \tDATA \tB2_T11: Rating = 86; rating_RT = 1.725; condition = hard; tolerance = 0.015\n',
#  '1710.3655 \tDATA \tB2_T12: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.018\n',
#  '1713.8955 \tDATA \tB2_T13: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.020999999999999998\n',
#  '1719.1153 \tDATA \tB2_T14: Rating = 83; rating_RT = 1.402; condition = hard; tolerance = 0.020999999999999998\n',
#  '1723.9122 \tDATA \tB2_T15: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.023999999999999997\n',
#  '1727.7317 \tDATA \tB2_T16: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.026999999999999996\n',
#  '1733.4119 \tDATA \tB2_T17: Rating = 79; rating_RT = 1.847; condition = hard; tolerance = 0.029999999999999995\n',
#  '1737.9153 \tDATA \tB2_T18: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.029999999999999995\n',
#  '1741.7287 \tDATA \tB2_T19: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.032999999999999995\n',
#  '1746.4311 \tDATA \tB2_T20: Rating = 42; rating_RT = 1.171; condition = hard; tolerance = 0.036\n',
#  '1751.2282 \tDATA \tB2_T21: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.039\n',
#  '1754.7462 \tDATA \tB2_T22: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.042\n',
#  '1759.7149 \tDATA \tB2_T23: Rating = 59; rating_RT = 1.437; condition = hard; tolerance = 0.030000000000000002\n',
#  '1764.2111 \tDATA \tB2_T24: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.033\n',
#  '1768.0279 \tDATA \tB2_T25: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.036000000000000004\n',
#  '1772.7481 \tDATA \tB2_T26: Rating = 44; rating_RT = 1.184; condition = hard; tolerance = 0.03900000000000001\n',
#  '1777.5481 \tDATA \tB2_T27: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04200000000000001\n',
#  '1781.3613 \tDATA \tB2_T28: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04500000000000001\n',
#  '1788.8308 \tDATA \tB2_T29: Rating = 25; rating_RT = 3.637; condition = hard; tolerance = 0.048000000000000015\n',
#  '1793.6278 \tDATA \tB2_T30: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.048000000000000015\n',
#  '1797.1475 \tDATA \tB2_T31: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03600000000000002\n',
#  '1802.2106 \tDATA \tB2_T32: Rating = 53; rating_RT = 1.531; condition = hard; tolerance = 0.03900000000000002\n',
#  '1806.7141 \tDATA \tB2_T33: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.02700000000000002\n',
#  '1810.5440 \tDATA \tB2_T34: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03000000000000002\n',
#  '1815.3474 \tDATA \tB2_T35: Rating = 41; rating_RT = 1.287; condition = hard; tolerance = 0.03000000000000002\n',
#  '1819.8456 \tDATA \tB2_T36: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03300000000000002\n',
#  '1823.3609 \tDATA \tB2_T37: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.036000000000000025\n',
#  '1829.0640 \tDATA \tB2_T38: Rating = 31; rating_RT = 1.87; condition = hard; tolerance = 0.024000000000000025\n',
#  '1833.5602 \tDATA \tB2_T39: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.027000000000000024\n',
#  '1837.3802 \tDATA \tB2_T40: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.015000000000000024\n',
#  '1842.4435 \tDATA \tB2_T41: Rating = 32; rating_RT = 1.231; condition = hard; tolerance = 0.018000000000000023\n',
#  '1846.9472 \tDATA \tB2_T42: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.021000000000000022\n',
#  '1850.7602 \tDATA \tB2_T43: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.02400000000000002\n',
#  '1855.8634 \tDATA \tB2_T44: Rating = 34; rating_RT = 1.272; condition = hard; tolerance = 0.02400000000000002\n',
#  '1860.6637 \tDATA \tB2_T45: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.02700000000000002\n',
#  '1864.4781 \tDATA \tB2_T46: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03000000000000002\n',
#  '1869.9465 \tDATA \tB2_T47: Rating = 71; rating_RT = 1.634; condition = hard; tolerance = 0.03300000000000002\n',
#  '1874.7448 \tDATA \tB2_T48: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.036000000000000025\n',
#  '1878.2800 \tDATA \tB2_T49: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03900000000000003\n',
#  '1882.9466 \tDATA \tB2_T50: Rating = 42; rating_RT = 1.153; condition = hard; tolerance = 0.03900000000000003\n',
#  '1887.4432 \tDATA \tB2_T51: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04200000000000003\n',
#  '1890.9626 \tDATA \tB2_T52: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04500000000000003\n',
#  '1914.6942 \tDATA \tB2_T53: Rating = None; rating_RT = 20; condition = hard; tolerance = 0.048000000000000036\n',
#  '1919.3129 \tDATA \tB2_T54: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.05100000000000004\n',
#  '1922.8094 \tDATA \tB2_T55: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.05100000000000004\n',
#  '1930.0793 \tDATA \tB2_T56: Rating = 58; rating_RT = 3.739; condition = hard; tolerance = 0.039000000000000035\n',
#  '1934.8768 \tDATA \tB2_T57: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.027000000000000034\n',
#  '1938.6957 \tDATA \tB2_T58: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.030000000000000034\n',
#  '1943.4925 \tDATA \tB2_T59: Rating = 72; rating_RT = 1.264; condition = hard; tolerance = 0.030000000000000034\n',
#  '1947.9924 \tDATA \tB2_T60: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.033000000000000036\n',
#  '1951.5125 \tDATA \tB2_T61: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03600000000000004\n',
#  '1956.7787 \tDATA \tB2_T62: Rating = 84; rating_RT = 1.434; condition = hard; tolerance = 0.03900000000000004\n',
#  '1961.2751 \tDATA \tB2_T63: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.042000000000000044\n',
#  '1964.7922 \tDATA \tB2_T64: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04500000000000005\n',
#  '1971.4584 \tDATA \tB2_T65: Rating = 17; rating_RT = 3.131; condition = hard; tolerance = 0.03300000000000004\n',
#  '1976.2605 \tDATA \tB2_T66: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.036000000000000046\n',
#  '1980.0785 \tDATA \tB2_T67: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03900000000000005\n',
#  '1986.4786 \tDATA \tB2_T68: Rating = 19; rating_RT = 2.572; condition = hard; tolerance = 0.02700000000000005\n',
#  '1991.2747 \tDATA \tB2_T69: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.030000000000000047\n',
#  '1995.0935 \tDATA \tB2_T70: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.018000000000000047\n',
#  '2000.8950 \tDATA \tB2_T71: Rating = 18; rating_RT = 2.269; condition = hard; tolerance = 0.021000000000000046\n',
#  '2005.3915 \tDATA \tB2_T72: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.024000000000000046\n',
#  '2008.9118 \tDATA \tB2_T73: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.024000000000000046\n',
#  '2014.8279 \tDATA \tB2_T74: Rating = 17; rating_RT = 2.385; condition = hard; tolerance = 0.027000000000000045\n',
#  '2054.0742 \tDATA \tB3_T0: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.030000000000000044\n',
#  '2057.8777 \tDATA \tB3_T1: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03300000000000004\n',
#  '2063.0738 \tDATA \tB3_T2: Rating = 34; rating_RT = 1.364; condition = hard; tolerance = 0.036000000000000046\n',
#  '2067.5942 \tDATA \tB3_T3: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03900000000000005\n',
#  '2071.0904 \tDATA \tB3_T4: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.02700000000000005\n',
#  '2075.9770 \tDATA \tB3_T5: Rating = 21; rating_RT = 1.054; condition = hard; tolerance = 0.030000000000000047\n',
#  '2080.7741 \tDATA \tB3_T6: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03300000000000005\n',
#  '2084.5918 \tDATA \tB3_T7: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03600000000000005\n',
#  '2089.5435 \tDATA \tB3_T8: Rating = 32; rating_RT = 1.117; condition = hard; tolerance = 0.039000000000000055\n',
#  '2094.3406 \tDATA \tB3_T9: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04200000000000006\n',
#  '2097.8602 \tDATA \tB3_T10: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04500000000000006\n',
#  '2102.3900 \tDATA \tB3_T11: Rating = 25; rating_RT = 0.999; condition = hard; tolerance = 0.04800000000000006\n',
#  '2106.8935 \tDATA \tB3_T12: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04800000000000006\n',
#  '2110.4066 \tDATA \tB3_T13: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03600000000000006\n',
#  '2115.0767 \tDATA \tB3_T14: Rating = 36; rating_RT = 1.139; condition = hard; tolerance = 0.03900000000000006\n',
#  '2119.8778 \tDATA \tB3_T15: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.042000000000000065\n',
#  '2123.6901 \tDATA \tB3_T16: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04500000000000007\n',
#  '2128.2098 \tDATA \tB3_T17: Rating = 20; rating_RT = 0.987; condition = hard; tolerance = 0.04800000000000007\n',
#  '2132.7078 \tDATA \tB3_T18: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04800000000000007\n',
#  '2136.2264 \tDATA \tB3_T19: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.05100000000000007\n',
#  '2141.1561 \tDATA \tB3_T20: Rating = 30; rating_RT = 1.097; condition = hard; tolerance = 0.054000000000000076\n',
#  '2145.6597 \tDATA \tB3_T21: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.05700000000000008\n',
#  '2149.4765 \tDATA \tB3_T22: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.06000000000000008\n',
#  '2154.1562 \tDATA \tB3_T23: Rating = 29; rating_RT = 1.153; condition = hard; tolerance = 0.06300000000000008\n',
#  '2158.6596 \tDATA \tB3_T24: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.05100000000000009\n',
#  '2162.1730 \tDATA \tB3_T25: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03900000000000009\n',
#  '2167.1425 \tDATA \tB3_T26: Rating = 22; rating_RT = 1.138; condition = hard; tolerance = 0.04200000000000009\n',
#  '2171.9393 \tDATA \tB3_T27: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.045000000000000095\n',
#  '2175.4595 \tDATA \tB3_T28: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.0480000000000001\n',
#  '2180.0755 \tDATA \tB3_T29: Rating = 23; rating_RT = 1.084; condition = hard; tolerance = 0.0510000000000001\n',
#  '2184.5723 \tDATA \tB3_T30: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.039000000000000104\n',
#  '2188.3924 \tDATA \tB3_T31: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04200000000000011\n',
#  '2193.5388 \tDATA \tB3_T32: Rating = 18; rating_RT = 1.614; condition = hard; tolerance = 0.04500000000000011\n',
#  '2198.0591 \tDATA \tB3_T33: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03300000000000011\n',
#  '2201.5555 \tDATA \tB3_T34: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03300000000000011\n',
#  '2206.2755 \tDATA \tB3_T35: Rating = 31; rating_RT = 1.189; condition = hard; tolerance = 0.021000000000000112\n',
#  '2211.0721 \tDATA \tB3_T36: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.02400000000000011\n',
#  '2214.5888 \tDATA \tB3_T37: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.02700000000000011\n',
#  '2219.6087 \tDATA \tB3_T38: Rating = 18; rating_RT = 1.488; condition = hard; tolerance = 0.03000000000000011\n',
#  '2224.1220 \tDATA \tB3_T39: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03300000000000011\n',
#  '2227.9256 \tDATA \tB3_T40: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.021000000000000112\n',
#  '2232.7719 \tDATA \tB3_T41: Rating = 24; rating_RT = 1.014; condition = hard; tolerance = 0.02400000000000011\n',
#  '2237.5920 \tDATA \tB3_T42: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.02400000000000011\n',
#  '2241.0883 \tDATA \tB3_T43: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.02700000000000011\n',
#  '2245.9583 \tDATA \tB3_T44: Rating = 25; rating_RT = 1.038; condition = hard; tolerance = 0.03000000000000011\n',
#  '2250.4751 \tDATA \tB3_T45: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03300000000000011\n',
#  '2254.2716 \tDATA \tB3_T46: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03300000000000011\n',
#  '2259.4747 \tDATA \tB3_T47: Rating = 29; rating_RT = 1.668; condition = hard; tolerance = 0.036000000000000115\n',
#  '2263.9716 \tDATA \tB3_T48: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03900000000000012\n',
#  '2267.8080 \tDATA \tB3_T49: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04200000000000012\n',
#  '2273.1211 \tDATA \tB3_T50: Rating = 20; rating_RT = 1.495; condition = hard; tolerance = 0.04200000000000012\n',
#  '2277.9244 \tDATA \tB3_T51: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04500000000000012\n',
#  '2281.4379 \tDATA \tB3_T52: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.033000000000000126\n',
#  '2286.7076 \tDATA \tB3_T53: Rating = 24; rating_RT = 1.436; condition = hard; tolerance = 0.03600000000000013\n',
#  '2291.5043 \tDATA \tB3_T54: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03600000000000013\n',
#  '2295.0219 \tDATA \tB3_T55: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.02400000000000013\n',
#  '2299.6575 \tDATA \tB3_T56: Rating = 25; rating_RT = 1.102; condition = hard; tolerance = 0.027000000000000128\n',
#  '2304.4555 \tDATA \tB3_T57: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.030000000000000127\n',
#  '2308.2744 \tDATA \tB3_T58: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.033000000000000126\n',
#  '2313.1711 \tDATA \tB3_T59: Rating = 22; rating_RT = 1.065; condition = hard; tolerance = 0.03600000000000013\n',
#  '2317.6740 \tDATA \tB3_T60: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03900000000000013\n',
#  '2321.2041 \tDATA \tB3_T61: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.042000000000000134\n',
#  '2326.1237 \tDATA \tB3_T62: Rating = 18; rating_RT = 1.089; condition = hard; tolerance = 0.04500000000000014\n',
#  '2330.9205 \tDATA \tB3_T63: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04500000000000014\n',
#  '2334.4372 \tDATA \tB3_T64: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04800000000000014\n',
#  '2340.1234 \tDATA \tB3_T65: Rating = 30; rating_RT = 1.853; condition = hard; tolerance = 0.05100000000000014\n',
#  '2344.9219 \tDATA \tB3_T66: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.039000000000000146\n',
#  '2348.7404 \tDATA \tB3_T67: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04200000000000015\n',
#  '2353.9033 \tDATA \tB3_T68: Rating = 30; rating_RT = 1.634; condition = hard; tolerance = 0.04500000000000015\n',
#  '2358.7070 \tDATA \tB3_T69: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.048000000000000154\n',
#  '2362.2233 \tDATA \tB3_T70: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.051000000000000156\n',
#  '2367.4699 \tDATA \tB3_T71: Rating = 23; rating_RT = 1.419; condition = hard; tolerance = 0.05400000000000016\n',
#  '2372.2734 \tDATA \tB3_T72: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04200000000000016\n',
#  '2376.0896 \tDATA \tB3_T73: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.045000000000000165\n',
#  '2381.2699 \tDATA \tB3_T74: Rating = 20; rating_RT = 1.652; condition = hard; tolerance = 0.045000000000000165\n',
#  '2582.5171 \tDATA \tB4_T0: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.194\n',
#  '2586.0372 \tDATA \tB4_T1: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.191\n',
#  '2591.5831 \tDATA \tB4_T2: Rating = 95; rating_RT = 2.015; condition = easy; tolerance = 0.188\n',
#  '2596.0871 \tDATA \tB4_T3: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.185\n',
#  '2599.6035 \tDATA \tB4_T4: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.197\n',
#  '2605.0534 \tDATA \tB4_T5: Rating = 89; rating_RT = 1.622; condition = easy; tolerance = 0.194\n',
#  '2609.8700 \tDATA \tB4_T6: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.191\n',
#  '2613.3677 \tDATA \tB4_T7: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.203\n',
#  '2618.4366 \tDATA \tB4_T8: Rating = 77; rating_RT = 1.538; condition = easy; tolerance = 0.2\n',
#  '2622.9333 \tDATA \tB4_T9: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.197\n',
#  '2626.7702 \tDATA \tB4_T10: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.194\n',
#  '2631.9498 \tDATA \tB4_T11: Rating = 100; rating_RT = 1.664; condition = easy; tolerance = 0.194\n',
#  '2636.4534 \tDATA \tB4_T12: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.191\n',
#  '2640.2696 \tDATA \tB4_T13: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.203\n',
#  '2645.7864 \tDATA \tB4_T14: Rating = 81; rating_RT = 1.688; condition = easy; tolerance = 0.2\n',
#  '2650.5829 \tDATA \tB4_T15: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.2\n',
#  '2654.4001 \tDATA \tB4_T16: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.197\n',
#  '2659.7362 \tDATA \tB4_T17: Rating = 81; rating_RT = 1.502; condition = easy; tolerance = 0.194\n',
#  '2664.2327 \tDATA \tB4_T18: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.191\n',
#  '2667.7527 \tDATA \tB4_T19: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.203\n',
#  '2672.7825 \tDATA \tB4_T20: Rating = 83; rating_RT = 1.197; condition = easy; tolerance = 0.2\n',
#  '2677.2858 \tDATA \tB4_T21: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.21200000000000002\n',
#  '2681.0991 \tDATA \tB4_T22: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20900000000000002\n',
#  '2685.9189 \tDATA \tB4_T23: Rating = 79; rating_RT = 1.289; condition = easy; tolerance = 0.22100000000000003\n',
#  '2690.7158 \tDATA \tB4_T24: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.21800000000000003\n',
#  '2694.2489 \tDATA \tB4_T25: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.21500000000000002\n',
#  '2699.4019 \tDATA \tB4_T26: Rating = 89; rating_RT = 1.635; condition = easy; tolerance = 0.21500000000000002\n',
#  '2704.2155 \tDATA \tB4_T27: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.21200000000000002\n',
#  '2707.7187 \tDATA \tB4_T28: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.22400000000000003\n',
#  '2713.6522 \tDATA \tB4_T29: Rating = 65; rating_RT = 2.401; condition = easy; tolerance = 0.22100000000000003\n',
#  '2718.4487 \tDATA \tB4_T30: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.21800000000000003\n',
#  '2721.9686 \tDATA \tB4_T31: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.21500000000000002\n',
#  '2727.5651 \tDATA \tB4_T32: Rating = 91; rating_RT = 2.064; condition = easy; tolerance = 0.21200000000000002\n',
#  '2732.3852 \tDATA \tB4_T33: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20900000000000002\n',
#  '2736.1852 \tDATA \tB4_T34: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20900000000000002\n',
#  '2741.6983 \tDATA \tB4_T35: Rating = 76; rating_RT = 1.985; condition = easy; tolerance = 0.20600000000000002\n',
#  '2746.5015 \tDATA \tB4_T36: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.203\n',
#  '2750.3180 \tDATA \tB4_T37: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.2\n',
#  '2756.0181 \tDATA \tB4_T38: Rating = 79; rating_RT = 1.872; condition = easy; tolerance = 0.21200000000000002\n',
#  '2760.5181 \tDATA \tB4_T39: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20900000000000002\n',
#  '2764.0313 \tDATA \tB4_T40: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.20600000000000002\n',
#  '2770.0345 \tDATA \tB4_T41: Rating = 84; rating_RT = 2.167; condition = easy; tolerance = 0.203\n',
#  '2774.5328 \tDATA \tB4_T42: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.2\n',
#  '2778.3680 \tDATA \tB4_T43: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.197\n',
#  '2783.4841 \tDATA \tB4_T44: Rating = 81; rating_RT = 1.303; condition = easy; tolerance = 0.197\n',
#  '2788.2817 \tDATA \tB4_T45: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.194\n',
#  '2791.8012 \tDATA \tB4_T46: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.191\n',
#  '2797.1176 \tDATA \tB4_T47: Rating = 89; rating_RT = 1.485; condition = easy; tolerance = 0.188\n',
#  '2801.9142 \tDATA \tB4_T48: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.188\n',
#  '2805.4497 \tDATA \tB4_T49: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.185\n',
#  '2810.1003 \tDATA \tB4_T50: Rating = 73; rating_RT = 1.135; condition = easy; tolerance = 0.197\n',
#  '2814.8973 \tDATA \tB4_T51: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.194\n',
#  '2818.4174 \tDATA \tB4_T52: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.191\n',
#  '2823.1303 \tDATA \tB4_T53: Rating = 77; rating_RT = 1.181; condition = easy; tolerance = 0.188\n',
#  '2827.9335 \tDATA \tB4_T54: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.2\n',
#  '2831.7471 \tDATA \tB4_T55: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.2\n',
#  '2836.9500 \tDATA \tB4_T56: Rating = 76; rating_RT = 1.672; condition = easy; tolerance = 0.197\n',
#  '2841.7470 \tDATA \tB4_T57: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.194\n',
#  '2845.2822 \tDATA \tB4_T58: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.191\n',
#  '2850.3835 \tDATA \tB4_T59: Rating = 80; rating_RT = 1.585; condition = easy; tolerance = 0.191\n',
#  '2855.1815 \tDATA \tB4_T60: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.188\n',
#  '2858.9999 \tDATA \tB4_T61: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.2\n',
#  '2863.9463 \tDATA \tB4_T62: Rating = 81; rating_RT = 1.419; condition = easy; tolerance = 0.197\n',
#  '2868.4499 \tDATA \tB4_T63: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.194\n',
#  '2871.9631 \tDATA \tB4_T64: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.191\n',
#  '2876.6329 \tDATA \tB4_T65: Rating = 76; rating_RT = 1.139; condition = easy; tolerance = 0.188\n',
#  '2881.4295 \tDATA \tB4_T66: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.185\n',
#  '2885.2476 \tDATA \tB4_T67: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.182\n',
#  '2890.5133 \tDATA \tB4_T68: Rating = 68; rating_RT = 1.431; condition = easy; tolerance = 0.182\n',
#  '2895.3165 \tDATA \tB4_T69: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.179\n',
#  '2898.8328 \tDATA \tB4_T70: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.176\n',
#  '2904.2457 \tDATA \tB4_T71: Rating = 85; rating_RT = 1.582; condition = easy; tolerance = 0.173\n',
#  '2909.0461 \tDATA \tB4_T72: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.185\n',
#  '2912.8671 \tDATA \tB4_T73: Rating = -1; rating_RT = -1; condition = easy; tolerance = 0.182\n',
#  '2917.5492 \tDATA \tB4_T74: Rating = 73; rating_RT = 1.15; condition = easy; tolerance = 0.194\n',
#  '3081.8604 \tDATA \tB5_T0: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04800000000000017\n',
#  '3085.6785 \tDATA \tB5_T1: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.05100000000000017\n',
#  '3091.2637 \tDATA \tB5_T2: Rating = 84; rating_RT = 1.769; condition = hard; tolerance = 0.03900000000000017\n',
#  '3096.0637 \tDATA \tB5_T3: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.027000000000000173\n',
#  '3099.8801 \tDATA \tB5_T4: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.030000000000000172\n',
#  '3105.2465 \tDATA \tB5_T5: Rating = 81; rating_RT = 1.538; condition = hard; tolerance = 0.033000000000000175\n',
#  '3110.0466 \tDATA \tB5_T6: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03600000000000018\n',
#  '3113.8600 \tDATA \tB5_T7: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03900000000000018\n',
#  '3118.6799 \tDATA \tB5_T8: Rating = 80; rating_RT = 1.287; condition = hard; tolerance = 0.02700000000000018\n',
#  '3123.1765 \tDATA \tB5_T9: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03000000000000018\n',
#  '3127.0133 \tDATA \tB5_T10: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03300000000000018\n',
#  '3132.0761 \tDATA \tB5_T11: Rating = 85; rating_RT = 1.249; condition = hard; tolerance = 0.03300000000000018\n',
#  '3136.8797 \tDATA \tB5_T12: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.036000000000000185\n',
#  '3140.3961 \tDATA \tB5_T13: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03900000000000019\n',
#  '3145.4462 \tDATA \tB5_T14: Rating = 82; rating_RT = 1.222; condition = hard; tolerance = 0.027000000000000187\n',
#  '3150.2462 \tDATA \tB5_T15: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.030000000000000186\n',
#  '3154.0594 \tDATA \tB5_T16: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.018000000000000186\n',
#  '3158.6291 \tDATA \tB5_T17: Rating = 82; rating_RT = 1.036; condition = hard; tolerance = 0.021000000000000185\n',
#  '3163.4255 \tDATA \tB5_T18: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.024000000000000184\n',
#  '3166.9460 \tDATA \tB5_T19: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.024000000000000184\n',
#  '3171.9255 \tDATA \tB5_T20: Rating = 78; rating_RT = 1.148; condition = hard; tolerance = 0.027000000000000184\n',
#  '3176.4292 \tDATA \tB5_T21: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.030000000000000183\n',
#  '3179.9459 \tDATA \tB5_T22: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03300000000000018\n',
#  '3185.0621 \tDATA \tB5_T23: Rating = 78; rating_RT = 1.289; condition = hard; tolerance = 0.036000000000000185\n',
#  '3189.5624 \tDATA \tB5_T24: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03900000000000019\n',
#  '3193.0755 \tDATA \tB5_T25: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.027000000000000187\n',
#  '3197.7119 \tDATA \tB5_T26: Rating = 21; rating_RT = 1.105; condition = hard; tolerance = 0.027000000000000187\n',
#  '3202.2088 \tDATA \tB5_T27: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.030000000000000186\n',
#  '3205.7273 \tDATA \tB5_T28: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03300000000000019\n',
#  '3211.2253 \tDATA \tB5_T29: Rating = 26; rating_RT = 1.664; condition = hard; tolerance = 0.03600000000000019\n',
#  '3215.7287 \tDATA \tB5_T30: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03600000000000019\n',
#  '3219.2452 \tDATA \tB5_T31: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.02400000000000019\n',
#  '3223.7751 \tDATA \tB5_T32: Rating = 17; rating_RT = 1.001; condition = hard; tolerance = 0.02700000000000019\n',
#  '3228.2786 \tDATA \tB5_T33: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.01500000000000019\n',
#  '3231.8085 \tDATA \tB5_T34: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.015\n',
#  '3237.3784 \tDATA \tB5_T35: Rating = 32; rating_RT = 1.754; condition = hard; tolerance = 0.015\n',
#  '3241.8748 \tDATA \tB5_T36: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.015\n',
#  '3245.6950 \tDATA \tB5_T37: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.018\n',
#  '3250.6078 \tDATA \tB5_T38: Rating = 22; rating_RT = 1.081; condition = hard; tolerance = 0.020999999999999998\n',
#  '3255.4116 \tDATA \tB5_T39: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.023999999999999997\n',
#  '3259.2282 \tDATA \tB5_T40: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.015\n',
#  '3264.1576 \tDATA \tB5_T41: Rating = 22; rating_RT = 1.099; condition = hard; tolerance = 0.018\n',
#  '3268.6613 \tDATA \tB5_T42: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.020999999999999998\n',
#  '3272.1780 \tDATA \tB5_T43: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.023999999999999997\n',
#  '3277.8110 \tDATA \tB5_T44: Rating = 26; rating_RT = 2.106; condition = hard; tolerance = 0.026999999999999996\n',
#  '3282.6074 \tDATA \tB5_T45: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.029999999999999995\n',
#  '3286.1278 \tDATA \tB5_T46: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.032999999999999995\n',
#  '3291.1909 \tDATA \tB5_T47: Rating = 29; rating_RT = 1.531; condition = hard; tolerance = 0.020999999999999994\n',
#  '3295.6929 \tDATA \tB5_T48: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.023999999999999994\n',
#  '3299.2107 \tDATA \tB5_T49: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.026999999999999993\n',
#  '3304.2070 \tDATA \tB5_T50: Rating = 29; rating_RT = 1.168; condition = hard; tolerance = 0.029999999999999992\n',
#  '3309.0104 \tDATA \tB5_T51: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.032999999999999995\n',
#  '3312.8239 \tDATA \tB5_T52: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.036\n',
#  '3317.5770 \tDATA \tB5_T53: Rating = 16; rating_RT = 1.221; condition = hard; tolerance = 0.039\n',
#  '3322.0738 \tDATA \tB5_T54: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.039\n',
#  '3325.8929 \tDATA \tB5_T55: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.042\n',
#  '3330.4935 \tDATA \tB5_T56: Rating = 22; rating_RT = 1.069; condition = hard; tolerance = 0.045000000000000005\n',
#  '3335.3090 \tDATA \tB5_T57: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04800000000000001\n',
#  '3338.8103 \tDATA \tB5_T58: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04800000000000001\n',
#  '3345.0434 \tDATA \tB5_T59: Rating = 28; rating_RT = 2.405; condition = hard; tolerance = 0.036000000000000004\n',
#  '3349.8438 \tDATA \tB5_T60: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03900000000000001\n',
#  '3353.6568 \tDATA \tB5_T61: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.04200000000000001\n',
#  '3358.2433 \tDATA \tB5_T62: Rating = 27; rating_RT = 1.053; condition = hard; tolerance = 0.03000000000000001\n',
#  '3362.7399 \tDATA \tB5_T63: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03300000000000001\n',
#  '3366.5598 \tDATA \tB5_T64: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.03600000000000001\n',
#  '3371.6897 \tDATA \tB5_T65: Rating = 28; rating_RT = 1.598; condition = hard; tolerance = 0.02400000000000001\n',
#  '3376.1933 \tDATA \tB5_T66: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.015\n',
#  '3379.7100 \tDATA \tB5_T67: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.018\n',
#  '3385.1892 \tDATA \tB5_T68: Rating = 34; rating_RT = 1.949; condition = hard; tolerance = 0.015\n',
#  '3390.0129 \tDATA \tB5_T69: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.018\n',
#  '3393.5096 \tDATA \tB5_T70: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.018\n',
#  '3398.5092 \tDATA \tB5_T71: Rating = 18; rating_RT = 1.469; condition = hard; tolerance = 0.020999999999999998\n',
#  '3403.0061 \tDATA \tB5_T72: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.023999999999999997\n',
#  '3406.8260 \tDATA \tB5_T73: Rating = -1; rating_RT = -1; condition = hard; tolerance = 0.026999999999999996\n',
#  '3411.6894 \tDATA \tB5_T74: Rating = 21; rating_RT = 1.031; condition = hard; tolerance = 0.026999999999999996\n']

# %%
ratings = [int(line[line.find('Rating =')+9:line.find('Rating =')+12].replace(';','')) for line in rating_lines]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-afae64a35dae> in <module>()
# ----> 1 ratings = [int(line[line.find('Rating =')+9:line.find('Rating =')+12].replace(';','')) for line in rating_lines]
#
# ValueError: invalid literal for int() with base 10: 'Non'

# %%
ratings = [line[line.find('Rating =')+9:line.find('Rating =')+12].replace(';','') for line in rating_lines]

# %%
[r.]

# %%
# Extract rating lines
rating_lines = [line for line in log if line.find('Rating =')!=-1]

# Extract rating data
if SBJ=='colin_test1':
    ratings = [line[line.find('Rating=')+7:line.find('Rating=')+9].replace(';','') for line in rating_lines]
else:
    ratings = [line[line.find('Rating =')+9:line.find('Rating =')+12].replace(';','') for line in rating_lines]


rating_rts = [float(line[line.find('rating_RT =')+12:line.find('rating_RT =')+16].replace(';','')) for line in rating_lines]

# get block_n and trial_n assuming no ratings in BT (training)
rating_blocks = [int(line[line.find('B')+1]) for line in rating_lines]
rating_trial_n = [int(line[line.find('_T')+2:line.find(':')]) for line in rating_lines]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-3c9ba78edeaf> in <module>()
#       5 else:
#       6     rating_lines = [line for line in log if line.find('Rating =')!=-1]
# ----> 7     ratings = [int(line[line.find('Rating =')+9:line.find('Rating =')+12].replace(';','')) for line in rating_lines]
#       8
#       9 rating_rts = [float(line[line.find('rating_RT =')+12:line.find('rating_RT =')+16].replace(';','')) for line in rating_lines]
#
# ValueError: invalid literal for int() with base 10: 'Non'

# %%
resp_lines = [line for line in log if line.find('Outcome=')!=-1]
data = pd.DataFrame({'Block': [line[line.find('B')+1] for line in resp_lines],
                     'Trial': [int(line[line.find('_T')+2:line.find(':')]) for line in resp_lines],
                     'Feedback': ['W' if line.count('WIN')>0 else \
                                  'L' if line.count('LOSE')>0 else \
                                  'S' for line in resp_lines],
                     'RT': [line[line.find('RT')+5:line.find('RT')+5+13].strip() for line in resp_lines],
                     'Tolerance': [float(line[line.find('tol')+12:line.find('\n')]) for line in resp_lines],
                     'Timestamp': [float(line[:line.find('.')+4]) for line in resp_lines],
                     'Rating': [-1 for line in resp_lines],
                     'Rating_RT': [-1 for line in resp_lines]
                    })

# Fix Reversals, Block, and missed RTs
for ix in range(len(data)):
    # Fix RTs
    if data['RT'][ix][0:2]=='-1':#No response
        data.loc[ix,'RT'] = -1
        #data.loc[ix,'Score'] = 0            # !!! may change depending on version !!!!
    else:# Real Responses
        if data['RT'][ix].find(';')!=-1:# shorter number of digits, clip ';'
            data.loc[ix,'RT'] = float(data['RT'][ix][:data['RT'][ix].find(';')])
        else:
            data.loc[ix,'RT'] = float(data['RT'][ix])
    
    # Fix Block coding
    if data['Block'][ix]=='T':# Training
        data.loc[ix,'Block'] = -1
    else:
        data.loc[ix,'Block'] = int(data['Block'][ix])

# Add ratings and rating_RTs
rating_ix = 0
for ix in range(len(data)):
    if data.loc[ix,'Block']==rating_blocks[rating_ix] and data.loc[ix,'Trial']==rating_trial_n[rating_ix]:
        data.loc[ix,'Rating'] = ratings[rating_ix]
        data.loc[ix,'Rating_RT'] = rating_rts[rating_ix]
        rating_ix += 1
    if rating_ix == len(ratings):
        break


data['Hit'] = [1 if abs(data['RT'][ix]-prdm['target']) <= data['Tolerance'][ix] else 0 for ix in range(len(data))]
data['Score'] = [0 if data['Feedback'][ix]=='S' or data['RT'][ix]== -1 else \
                 100 if data['Feedback'][ix]=='W' else -100 for ix in range(len(data))]

# Mark trials with bad feedback (apparently my logic has error up to 10 ms... damn it!)
data['bad_fb'] = [False if data['Feedback'][ix]=='S' or data['RT'][ix]==-1 or \
                  (data['Feedback'][ix]=='W' and data['Hit'][ix]==1) or \
                  (data['Feedback'][ix]=='L' and data['Hit'][ix]==0) \
                  else True for ix in range(len(data))]

# Add condition based on logging version
if prdm['prdm_version'][0]=='2' or prdm['prdm_version'] in ['3.0','3.1']:
    data['Condition'] = [line[line.find('condition')+12:line.find('condition')+16] for line in resp_lines]
else:
    data['Condition'] = [line[line.find('_type')+8:line.find('_type')+12] for line in resp_lines]
    
# Calculate ITIs starting on second trial, accounting for ratings
data['ITI'] = [0 if ix==0 else \
               data['Timestamp'][ix]-data['Timestamp'][ix-1]-prdm['trl_len'] if data['Rating'][ix]==-1 \
               else data['Timestamp'][ix]-data['Timestamp'][ix-1]-prdm['rating_trl_len']-data['Rating_RT'][ix] \
               for ix in range(len(data))]

# first test run was messed up, 2x rating_delay on all non-rating trials too
if SBJ=='colin_test1':
    for ix in range(len(data)):
        if data['Rating'][ix]==-1:
            data.loc[ix,'ITI'] = data.loc[ix,'ITI']-prdm['rating_delay']

data.loc[data['Trial']==0,'ITI'] = 0
data.loc[data['Block']==-1,'ITI'] = 0

# Match real ITIs to ITI categories
ITI_bin_edges = np.insert(ITI_bounds, ITI_bounds.shape[0], prdm['ITIs'][-1]+0.1)
ITI_bin_edges = np.insert(ITI_bin_edges, 0, 0)
data['ITI type'] = [prdm['ITIs'][np.argmax(np.histogram(data['ITI'][ix],bins=ITI_bin_edges)[0])]\
        if data['ITI'][ix]!=0 else 0 for ix in range(len(data))]
# if len(prdm['ITIs'])==4:    # target_time v1.8.5+
# elif len(prdm['ITIs'])==3:  # target_time v1.8.4 and below
# else:               # Errors for anything besides len(ITIs)==3,4
#     assert len(prdm['ITIs'])==4
            
# Print stats on bad feedback
if any(data['bad_fb']):
    bad_ix = [ix for ix in range(len(data)) if data['bad_fb'][ix]]
    tmp = data.ix[bad_ix]
    tmp['error'] = abs(tmp['RT']-prdm['target'])
    tmp['error-tol'] = tmp['Tolerance']-tmp['error']
    print 'WARNING!!! Bad feedback found on {0} trials!'.format(len(bad_ix))
    print 'Max error-tolerance = {0}, mean = {1}'.format(np.max(tmp['error-tol']),np.mean(np.abs(tmp['error-tol'])))
    tmp.ix[:,{'Tolerance','error','WIN','Hit','err-tol'}]
# Out:
# WARNING!!! Bad feedback found on 37 trials!
# Max error-tolerance = 0.01177224519, mean = 0.00579210484189

# %%
# print(SBJ,' n_trials = ',len(data))
# for cond in data['Condition'].unique():
#     print('==============', cond, '==============')
#     print('Accuracy:', data[data['Condition']==cond]['Hit'].mean())
#     print('--> correct = ', data[data['Condition']==cond]['Hit'].sum(),\
#           '/', len(data[data['Condition']==cond]['Hit']))
#     print('n_reverse:', data[data['Condition']==cond]['Reversal'].sum())

# %% [markdown]
# ### Save Behavioral Data

# %%
behav_fname = os.path.join(sbj_dir,'03_events',SBJ+'_behav.csv')

data.to_csv(behav_fname,index_label='Total_Trial')

# %%
# Check ITI computation and timing
# ix = 42
# if data['Rating'][ix]==-1:
#     print 'no rating: ', data['Rating'][ix], data['Rating_RT'][ix], 'last_t:', data['Timestamp'][ix-1], \
#         'curr_t:', data['Timestamp'][ix], prdm['trl_len'], data['Timestamp'][ix]-data['Timestamp'][ix-1]-prdm['trl_len']
# else:
#     print 'ys rating: ', data['Rating'][ix], data['Rating_RT'][ix], 'last_t:', data['Timestamp'][ix-1], 'curr_t:', data['Timestamp'][ix], \
#         data['Timestamp'][ix]-data['Timestamp'][ix-1]-prdm['rating_trl_len']-data['Rating_RT'][ix]
# Out:
# no rating:  -1 -1.0 last_t: 303.381 curr_t: 307.901 2.8 1.72

# %%
pd.set_option('max_rows', 75)
data[data['Block']==5]
# Out:
#     Block Feedback        RT  Rating  Rating_RT  Timestamp  Tolerance  Trial  \
# 410     5        L  0.819728      -1      -1.00   2859.748      0.033      0
# 411     5        L   1.66135      -1      -1.00   2863.567      0.036      1
# 412     5        L   1.39096       1       1.86   2869.936      0.039      2
# 413     5        L   1.06928      -1      -1.00   2873.471      0.042      3
# 414     5        L   1.23602      -1      -1.00   2876.989      0.045      4
# 415     5        L    1.1638       1       2.59   2884.091      0.048      5
# 416     5        W   1.01386      -1      -1.00   2887.926      0.036      6
# 417     5        L   1.17148      -1      -1.00   2891.744      0.039      7
# 418     5        W   0.96937       3       1.70   2898.247      0.027      8
# 419     5        W   1.00769      -1      -1.00   2902.082      0.015      9
# 420     5        S   1.02042      -1      -1.00   2905.600      0.015     10
# 421     5        L  0.762006       1       2.10   2912.503      0.018     11
# 422     5        L  0.787871      -1      -1.00   2916.037      0.021     12
# 423     5        L   1.17255      -1      -1.00   2919.555      0.024     13
# 424     5        L  0.971877       0       3.02   2927.092      0.027     14
# 425     5        L  0.951947      -1      -1.00   2930.910      0.030     15
# 426     5        L   1.20763      -1      -1.00   2934.428      0.033     16
# 427     5        L  0.921283       3       2.10   2941.031      0.036     17
# 428     5        S   1.07056      -1      -1.00   2944.865      0.036     18
# 429     5        W   1.03046      -1      -1.00   2948.683      0.024     19
# 430     5        L   1.04813       2       1.95   2955.436      0.027     20
# 431     5        L   1.07301      -1      -1.00   2958.971      0.030     21
# 432     5        L   0.89686      -1      -1.00   2962.489      0.033     22
# 433     5        L   1.03498       2       3.10   2970.092      0.036     23
# 434     5        L   1.24529      -1      -1.00   2973.926      0.039     24
# 435     5        S   1.10122      -1      -1.00   2977.444      0.039     25
# 436     5        W  0.961145       7       2.77   2985.031      0.027     26
# 437     5        L   1.13588      -1      -1.00   2988.849      0.030     27
# 438     5        L   1.13816      -1      -1.00   2992.667      0.033     28
# 439     5        S  0.928569       4       3.04   3000.521      0.033     29
# 440     5        L  0.888135      -1      -1.00   3004.055      0.036     30
# 441     5        L  0.888356      -1      -1.00   3007.873      0.039     31
# 442     5        L  0.952092       1       2.61   3014.992      0.042     32
# 443     5        L   1.30049      -1      -1.00   3018.527      0.045     33
# 444     5        S   1.12196      -1      -1.00   3022.062      0.045     34
# 445     5        L   1.12429       2       2.02   3028.881      0.048     35
# 446     5        L   1.17605      -1      -1.00   3032.699      0.051     36
# 447     5        L   1.08616      -1      -1.00   3036.218      0.054     37
# 448     5        W    0.9721       2       2.18   3042.904      0.042     38
# 449     5        L  0.928125      -1      -1.00   3046.738      0.045     39
# 450     5        L   1.19511      -1      -1.00   3050.556      0.048     40
# 451     5        L   1.13518       2       2.55   3057.909      0.051     41
# 452     5        L   1.07751      -1      -1.00   3061.445      0.054     42
# 453     5        L   1.11115      -1      -1.00   3064.962      0.057     43
# 454     5        W  0.989715       0       2.20   3071.665      0.045     44
# 455     5        L  0.822017      -1      -1.00   3075.500      0.048     45
# 456     5        L   1.26785      -1      -1.00   3079.018      0.051     46
# 457     5        L  0.920238       1       1.90   3085.737      0.054     47
# 458     5        L  0.700297      -1      -1.00   3089.555      0.057     48
# 459     5        L   1.30053      -1      -1.00   3093.073      0.060     49
# 460     5        L   1.20046       1       2.28   3099.876      0.063     50
# 461     5        W   1.00737      -1      -1.00   3103.694      0.051     51
# 462     5        L   1.18324      -1      -1.00   3107.212      0.054     52
# 463     5        S   1.13341       2       2.96   3114.682      0.054     53
# 464     5        W  0.998167      -1      -1.00   3118.533      0.042     54
# 465     5        L   1.18088      -1      -1.00   3122.351      0.045     55
# 466     5        W  0.958452       1       2.03   3128.871      0.033     56
# 467     5        S  0.986482      -1      -1.00   3132.405      0.033     57
# 468     5        L  0.963376      -1      -1.00   3136.223      0.036     58
# 469     5        L  0.896768       3       2.52   3143.260      0.039     59
# 470     5        L   1.10648      -1      -1.00   3146.778      0.042     60
# 471     5        L  0.906854      -1      -1.00   3150.296      0.045     61
# 472     5        W  0.962887      25       2.03   3157.132      0.033     62
# 473     5        L  0.927601      -1      -1.00   3160.666      0.036     63
# 474     5        L    1.1328      -1      -1.00   3164.184      0.039     64
# 475     5        L   1.12114      26       3.05   3171.738      0.042     65
# 476     5        L   1.18756      -1      -1.00   3175.272      0.045     66
# 477     5        L  0.919851      -1      -1.00   3178.790      0.048     67
# 478     5        L  0.921939       2       1.93   3185.543      0.051     68
# 479     5        S   1.01922      -1      -1.00   3189.077      0.051     69
# 480     5        W   1.00705      -1      -1.00   3192.579      0.039     70
# 481     5        L   1.19479       2       1.73   3199.115      0.042     71
# 482     5        W  0.971692      -1      -1.00   3202.950      0.030     72
# 483     5        S  0.928207      -1      -1.00   3206.468      0.030     73
# 484     5        W   1.02012       1       2.65   3213.937      0.018     74
#
#      Hit  Score bad_fb Condition    ITI  ITI type
# 410    0   -100  False      hard  0.000       0.0
# 411    0   -100  False      hard  1.019       1.0
# 412    0   -100  False      hard  0.709       0.7
# 413    0   -100  False      hard  0.735       0.7
# 414    0   -100  False      hard  0.718       0.7
# 415    0   -100  False      hard  0.712       0.7
# 416    1    100  False      hard  1.035       1.0
# 417    0   -100  False      hard  1.018       1.0
# 418    0    100   True      hard  1.003       1.0
# 419    1    100  False      hard  1.035       1.0
# 420    0      0  False      hard  0.718       0.7
# 421    0   -100  False      hard  1.003       1.0
# 422    0   -100  False      hard  0.734       0.7
# 423    0   -100  False      hard  0.718       0.7
# 424    0   -100  False      hard  0.717       0.7
# 425    0   -100  False      hard  1.018       1.0
# 426    0   -100  False      hard  0.718       0.7
# 427    0   -100  False      hard  0.703       0.7
# 428    0      0  False      hard  1.034       1.0
# 429    0    100   True      hard  1.018       1.0
# 430    0   -100  False      hard  1.003       1.0
# 431    0   -100  False      hard  0.735       0.7
# 432    0   -100  False      hard  0.718       0.7
# 433    1   -100   True      hard  0.703       0.7
# 434    0   -100  False      hard  1.034       1.0
# 435    0      0  False      hard  0.718       0.7
# 436    0    100   True      hard  1.017       1.0
# 437    0   -100  False      hard  1.018       1.0
# 438    0   -100  False      hard  1.018       1.0
# 439    0      0  False      hard  1.014       1.0
# 440    0   -100  False      hard  0.734       0.7
# 441    0   -100  False      hard  1.018       1.0
# 442    0   -100  False      hard  0.709       0.7
# 443    0   -100  False      hard  0.735       0.7
# 444    0      0  False      hard  0.735       0.7
# 445    0   -100  False      hard  0.999       1.0
# 446    0   -100  False      hard  1.018       1.0
# 447    0   -100  False      hard  0.719       0.7
# 448    1    100  False      hard  0.706       0.7
# 449    0   -100  False      hard  1.034       1.0
# 450    0   -100  False      hard  1.018       1.0
# 451    0   -100  False      hard  1.003       1.0
# 452    0   -100  False      hard  0.736       0.7
# 453    0   -100  False      hard  0.717       0.7
# 454    1    100  False      hard  0.703       0.7
# 455    0   -100  False      hard  1.035       1.0
# 456    0   -100  False      hard  0.718       0.7
# 457    0   -100  False      hard  1.019       1.0
# 458    0   -100  False      hard  1.018       1.0
# 459    0   -100  False      hard  0.718       0.7
# 460    0   -100  False      hard  0.723       0.7
# 461    1    100  False      hard  1.018       1.0
# 462    0   -100  False      hard  0.718       0.7
# 463    0      0  False      hard  0.710       0.7
# 464    1    100  False      hard  1.051       1.0
# 465    0   -100  False      hard  1.018       1.0
# 466    0    100   True      hard  0.690       0.7
# 467    1      0  False      hard  0.734       0.7
# 468    0   -100  False      hard  1.018       1.0
# 469    0   -100  False      hard  0.717       0.7
# 470    0   -100  False      hard  0.718       0.7
# 471    0   -100  False      hard  0.718       0.7
# 472    0    100   True      hard  1.006       1.0
# 473    0   -100  False      hard  0.734       0.7
# 474    0   -100  False      hard  0.718       0.7
# 475    0   -100  False      hard  0.704       0.7
# 476    0   -100  False      hard  0.734       0.7
# 477    0   -100  False      hard  0.718       0.7
# 478    0   -100  False      hard  1.023       1.0
# 479    1      0  False      hard  0.734       0.7
# 480    1    100  False      hard  0.702       0.7
# 481    0   -100  False      hard  1.006       1.0
# 482    1    100  False      hard  1.035       1.0
# 483    0      0  False      hard  0.718       0.7
# 484    0    100   True      hard  1.019       1.0
