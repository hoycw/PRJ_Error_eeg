# %%
# coding: utf-8

# In[1]:

from __future__ import division
#get_ipython().magic(u'matplotlib inline')
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.io as io
import pickle

import scipy.stats


# In[2]:

SBJ = 'EEG01'#raw_input('Enter SBJ ID to process:')#'IR63'


# In[3]:
#prj_dir = '/Volumes/hoycw_clust/PRJ_Error_eeg/'
prj_dir = '/Users/sheilasteiner/Desktop/Knight_Lab/PRJ_Error_eeg/'
results_dir = prj_dir+'results/'
fig_type = '.png'
data_dir = prj_dir+'data/'
sbj_dir  = data_dir+SBJ+'/'


# ### Load paradigm parameters

# In[4]:

prdm_fname = os.path.join(sbj_dir,'03_events',SBJ+'_odd_prdm_vars.pkl')
with open(prdm_fname, 'rb') as f:
    prdm = pickle.load(f)


# In[6]:

behav_fname = os.path.join(sbj_dir,'03_events',SBJ+'_behav_oddball.csv')
data = pd.read_csv(behav_fname)

# %%
# In[7]:

# Label post-correct (PC), post-error (PE) trials
data['PE'] = [False for _ in range(len(data))]
for ix in range(len(data)):
    # Exclude training data and first trial of the block
    if (data.loc[ix,'Block']!=-1) and (data.loc[ix,'Trial']!=0):
        if data.loc[ix-1,'Hit']==0:
            data.loc[ix,'PE'] = True

# Find middle of blocks to plot accuracy
block_start_ix = data[data['Trial']==0].index
block_mid_ix = [ix+prdm['n_trials']/2 for ix in block_start_ix[1:]]

# Add in full_vis + E/H training: 0:4 + 5:19 = 10; 20:34 = 27.5
block_mid_ix.insert(0,np.mean([prdm['n_training'],
                               2*prdm['n_training']]))   #examples
block_mid_ix.insert(0,np.mean([0,prdm['n_training']]))
#easy training (would be 12.5 if splitting examples/train)

# %%
# In[10]:
accurate_tar_ratio = []
accurate_std_ratio = []
accurate_odd_ratio = []
# Compute accuracy per condition
for ix in range(np.max(data['Block'])):
    block_data = data[data['Block'] == ix]
    accurate_tar_trials = []
    tar_trials = block_data[block_data['Condition'] == 'tar'].index
    for x in tar_trials:
        if data.loc[x,'Hit'] == 1:
            accurate_tar_trials.append(x)
    accurate_tar_ratio.append(np.size(accurate_tar_trials)/np.size(tar_trials))
    print(accurate_tar_ratio)
    accurate_std_trials = []
    std_trials = block_data[block_data['Condition'] == 'std'].index
    for x in std_trials:
        if data.loc[x,'Miss'] == 0:
            accurate_std_trials.append(x)
    accurate_std_ratio.append(np.size(accurate_std_trials)/np.size(std_trials))

    accurate_odd_trials = []
    odd_trials = data[data['Condition'] == 'odd', data['Block'] == ix].index
    for x in odd_trials:
        if data.loc[x,'Miss'] == 0:
            accurate_odd_trials.append(x)
    accurate_odd_ratio.append(np.size(accurate_odd_trials)/np.size(odd_trials))
#acc_ITI = data['Hit'].groupby([data['ITI type'],data['Condition']]).mean()
for ix in range(len(data)):
    data.loc[ix,'Accuracy'] = accuracy[data.loc[ix,'Block'],data.loc[ix,'Condition']]
    #data.loc[ix,'Acc_ITI'] = acc_ITI[data.loc[ix,'ITI'],data.loc[ix,'Condition']]

data_all = data
# Exclude: Training/Examples, non-responses, first trial of each block
if data[data['RT']<0].shape[0]>0:
    print ('WARNING: '+str(data[data['RT']<0].shape[0])+' trials with no response!')
data = data[(data['Block']!=-1) & (data['RT']>0) & (data['ITI']>0)]


# WARNING: I need to go across subjects to get variance in accuracy by ITI
plot = sns.factorplot(data=data,x='Condition',y='accuracy',kind='point',sharey=False,
                      ci=95);#,order=ITI_plot_order
#plot.set(alpha=0.5)
plt.subplots_adjust(top=0.9)
plot.fig.suptitle(SBJ) # can also get the figure from plt.gcf()

plt.savefig(results_dir+'BHV/ODD/accuracy/'+SBJ+'_acc_condition'+fig_type)
###
###
### # ## Look for behavioral adjustments following short and long responses
###
### # In[41]:
###
### plot = sns.factorplot(data=data_PL,x='ITI type',y='RT',hue='PE',col='Condition',kind='point',
###                ci=95,order=prdm['ITIs']);
### plt.subplots_adjust(top=0.9)
### plot.fig.suptitle(SBJ+'_post-long') # can also get the figure from plt.gcf()
###
### # plt.savefig(results_dir+'RT_plots/'+SBJ+'_RT_PE_ITI_hit'+fig_type)
### plot2 = sns.factorplot(data=data_PS,x='ITI type',y='RT',hue='PE',col='Condition',kind='point',
###                ci=95,order=prdm['ITIs']);
### plt.subplots_adjust(top=0.9)
### plot2.fig.suptitle(SBJ+'_post-short') # can also get the figure from plt.gcf()
###
### # plt.savefig(results_dir+'RT_plots/'+SBJ+'_RT_PE_ITI_hit'+fig_type)
# Out:
#      Total_Trial  Block  Hit  Miss        RT  Timestamp  Trial  Score  \
# 10            10      0    0     0 -1.000000     89.261      0      0
# 11            11      0    0     0 -1.000000     90.961      1      0
# 12            12      0    0     0 -1.000000     92.461      2      0
# 13            13      0    0     0 -1.000000     94.161      3      0
# 14            14      0    0     0 -1.000000     95.661      4      0
# 15            15      0    1     0  0.277557     97.161      5    100
# 16            16      0    0     0 -1.000000     98.660      6      0
# 17            17      0    0     0 -1.000000    100.360      7      0
# 18            18      0    0     0 -1.000000    102.060      8      0
# 19            19      0    0     0 -1.000000    103.760      9      0
# 20            20      0    0     0 -1.000000    105.460     10      0
# 21            21      0    0     0 -1.000000    106.960     11      0
# 22            22      0    0     0 -1.000000    108.460     12      0
# 23            23      0    1     0  0.275274    110.159     13    100
# 24            24      0    0     0 -1.000000    111.859     14      0
# 25            25      0    0     0 -1.000000    113.559     15      0
# 26            26      0    0     1  0.252996    115.259     16      0
# 27            27      0    0     0 -1.000000    116.959     17      0
# 28            28      0    0     0 -1.000000    118.659     18      0
# 29            29      0    0     0 -1.000000    120.359     19      0
# 30            30      0    0     0 -1.000000    121.858     20      0
# 31            31      0    0     0 -1.000000    123.358     21      0
# 32            32      0    1     0  0.315182    124.858     22    100
# 33            33      0    0     0 -1.000000    126.558     23      0
# 34            34      0    0     0 -1.000000    128.258     24      0
# 35            35      0    0     0 -1.000000    129.758     25      0
# 36            36      0    0     0 -1.000000    131.458     26      0
# 37            37      0    0     0 -1.000000    132.957     27      0
# 38            38      0    0     0 -1.000000    134.457     28      0
# 39            39      0    0     0 -1.000000    136.157     29      0
# ..           ...    ...  ...   ...       ...        ...    ...    ...
# 110          110      0    0     0 -1.000000    250.447    100      0
# 111          111      0    0     0 -1.000000    252.147    101      0
# 112          112      0    0     0 -1.000000    253.847    102      0
# 113          113      0    0     0 -1.000000    255.347    103      0
# 114          114      0    0     0 -1.000000    256.847    104      0
# 115          115      0    0     0 -1.000000    258.347    105      0
# 116          116      0    1     0  0.351654    260.046    106    100
# 117          117      0    0     0 -1.000000    261.546    107      0
# 118          118      0    0     0 -1.000000    263.046    108      0
# 119          119      0    0     0 -1.000000    264.746    109      0
# 120          120      0    0     0 -1.000000    266.446    110      0
# 121          121      0    0     0 -1.000000    268.146    111      0
# 122          122      0    1     0  0.269408    269.846    112    100
# 123          123      0    0     0 -1.000000    271.345    113      0
# 124          124      0    0     0 -1.000000    273.045    114      0
# 125          125      0    0     0 -1.000000    274.545    115      0
# 126          126      0    0     0 -1.000000    276.245    116      0
# 127          127      0    0     0 -1.000000    277.945    117      0
# 128          128      0    0     0 -1.000000    279.445    118      0
# 129          129      0    0     0 -1.000000    281.145    119      0
# 130          130      0    0     0 -1.000000    282.844    120      0
# 131          131      0    0     0 -1.000000    284.344    121      0
# 132          132      0    0     0 -1.000000    285.844    122      0
# 133          133      0    0     0 -1.000000    287.544    123      0
# 134          134      0    0     0 -1.000000    289.244    124      0
# 135          135      0    0     0 -1.000000    290.944    125      0
# 136          136      0    0     0 -1.000000    292.644    126      0
# 137          137      0    0     0 -1.000000    294.343    127      0
# 138          138      0    0     0 -1.000000    295.843    128      0
# 139          139      0    0     0 -1.000000    297.443    129      0
#
#     Condition  ITI     PE
# 10        std  0.0  False
# 11        std  1.5   True
# 12        std  1.3   True
# 13        std  1.5   True
# 14        std  1.3   True
# 15        tar  1.3   True
# 16        std  1.3  False
# 17        std  1.5   True
# 18        std  1.5   True
# 19        std  1.5   True
# 20        odd  1.5   True
# 21        std  1.3   True
# 22        std  1.3   True
# 23        tar  1.5   True
# 24        std  1.5  False
# 25        std  1.5   True
# 26        std  1.5   True
# 27        std  1.5   True
# 28        std  1.5   True
# 29        std  1.5   True
# 30        std  1.3   True
# 31        std  1.3   True
# 32        tar  1.3   True
# 33        std  1.5  False
# 34        odd  1.5   True
# 35        std  1.3   True
# 36        std  1.5   True
# 37        odd  1.3   True
# 38        std  1.3   True
# 39        std  1.5   True
# ..        ...  ...    ...
# 110       std  1.5   True
# 111       std  1.5   True
# 112       std  1.5   True
# 113       std  1.3   True
# 114       odd  1.3   True
# 115       std  1.3   True
# 116       tar  1.5   True
# 117       std  1.3  False
# 118       std  1.3   True
# 119       std  1.5   True
# 120       std  1.5   True
# 121       std  1.5   True
# 122       tar  1.5   True
# 123       std  1.3  False
# 124       std  1.5   True
# 125       std  1.3   True
# 126       std  1.5   True
# 127       std  1.5   True
# 128       std  1.3   True
# 129       std  1.5   True
# 130       std  1.5   True
# 131       std  1.3   True
# 132       std  1.3   True
# 133       std  1.5   True
# 134       odd  1.5   True
# 135       std  1.5   True
# 136       std  1.5   True
# 137       odd  1.5   True
# 138       std  1.3   True
# 139       std  1.5   True
#
# [130 rows x 11 columns]
# here!
# [1.0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-33bc0867b292> in <module>()
#      17     print(accurate_tar_ratio)
#      18     accurate_std_trials = []
# ---> 19     std_trials = data[data['Condition'] == 'std', data['Block'] == ix].index
#      20     for x in std_trials:
#      21         if data.loc[x,'Miss'] == 0:
#
# /Users/sheilasteiner/opt/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /Users/sheilasteiner/opt/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0       True
# 1       True
# 2       True
# 3      False
# 4       True
# 5       True
# 6      False
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15     False
# 16      True
# 17      True
# 18      True
# 19      True
# 20     False
# 21      True
# 22      True
# 23     False
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 370    False
# 371     True
# 372     True
# 373     True
# 374     True
# 375    False
# 376     True
# 377    False
# 378     True
# 379     True
# 380    False
# 381     True
# 382     True
# 383     True
# 384    False
# 385     True
# 386     True
# 387     True
# 388    False
# 389     True
# 390     True
# 391     True
# 392    False
# 393    False
# 394     True
# 395    False
# 396     True
# 397    False
# 398     True
# 399     True
# Name: Condition, Length: 400, dtype: bool, 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 370    False
# 371    False
# 372    False
# 373    False
# 374    False
# 375    False
# 376    False
# 377    False
# 378    False
# 379    False
# 380    False
# 381    False
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Name: Block, Length: 400, dtype: bool)' is an invalid key
